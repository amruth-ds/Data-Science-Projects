# %%
import nltk 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize 
from string import punctuation
stop_words = set(stopwords.words('english'))

# %%
#POS tagging helps provide context to the sentence

# %%
text = word_tokenize("And now for something completely different arent")
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ'),
#  ('arent', 'NN')]

# %%
nltk.help.upenn_tagset('VBZ')
# Out:
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...

# %%
nltk.pos_tag(word_tokenize("The sailor dogs the hatch"))
# Out:
# [('The', 'DT'),
#  ('sailor', 'NN'),
#  ('dogs', 'VBZ'),
#  ('the', 'DT'),
#  ('hatch', 'NN')]

# %%
nltk.pos_tag(word_tokenize("dogs are barking a lot on the street"))
# Out:
# [('dogs', 'NNS'),
#  ('are', 'VBP'),
#  ('barking', 'VBG'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('street', 'NN')]

# %%
#Dummy text 
txt = "Sukanya, Rajib and Naba are my good friends."\
    "Sukanya is getting married next year. " \
    "Marriage is a big step in one’s life." \
    "It is both exciting and frightening. " \
    "But friendship is a sacred bond between people." \
    "It is a special kind of love between us. " \
    "Many of you must have tried searching for a friend "\
    "but never found the right one."

# %%
def clean_txt(sent):
    tokens = word_tokenize(sent.lower().replace('[^a-z ]',''))
    stop_updated = stopwords.words("english") + list(punctuation) + ["..."] + \
    ["would", "could","told","subject"]
    text = [term for term in tokens if term not in stop_updated and len(term) > 2] 
    res = " ".join(text)
    return res

# %%
wordsList = [word for word in clean_txt(txt).split(' ') ]

# %%
#  Using a Tagger. Which is part-of-speech  
    # tagger or POS-tagger.  
tagged = nltk.pos_tag(wordsList) 
print(tagged)
# Out:
# [('sukanya', 'NN'), ('rajib', 'NN'), ('naba', 'RB'), ('good', 'JJ'), ('friends.sukanya', 'NN'), ('getting', 'VBG'), ('married', 'VBN'), ('next', 'JJ'), ('year', 'NN'), ('marriage', 'NN'), ('big', 'JJ'), ('step', 'NN'), ('one', 'CD'), ('life.it', 'NN'), ('exciting', 'VBG'), ('frightening', 'VBG'), ('friendship', 'NN'), ('sacred', 'VBD'), ('bond', 'NN'), ('people.it', 'NN'), ('special', 'JJ'), ('kind', 'NN'), ('love', 'VBD'), ('many', 'JJ'), ('must', 'MD'), ('tried', 'VB'), ('searching', 'VBG'), ('friend', 'NN'), ('never', 'RB'), ('found', 'VBD'), ('right', 'RB'), ('one', 'CD')]

# %%
nltk.help.upenn_tagset('JJ')
# Out:
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...

# %%
### using built in corpus

# %%
alice = nltk.corpus.gutenberg.words('carroll-alice.txt')
alice_str = " ".join(alice)

# %%
wordsList = [word for word in clean_txt(alice_str).split(' ') ]

# %%
nltk.pos_tag(wordsList)
# Out:
# [('alice', 'NN'),
#  ('adventures', 'NNS'),
#  ('wonderland', 'VBP'),
#  ('lewis', 'RB'),
#  ('carroll', 'JJ'),
#  ('1865', 'CD'),
#  ('chapter', 'NN'),
#  ('rabbit', 'NN'),
#  ('hole', 'JJ'),
#  ('alice', 'NN'),
#  ('beginning', 'VBG'),
#  ('get', 'VB'),
#  ('tired', 'JJ'),
#  ('sitting', 'VBG'),
#  ('sister', 'JJ'),
#  ('bank', 'NN'),
#  ('nothing', 'NN'),
#  ('twice', 'RB'),
#  ('peeped', 'VBD'),
#  ('book', 'NN'),
#  ('sister', 'NN'),
#  ('reading', 'NN'),
#  ('pictures', 'NNS'),
#  ('conversations', 'NNS'),
#  ('use', 'VBP'),
#  ('book', 'NN'),
#  ('thought', 'NN'),
#  ('alice', 'NN'),
#  ('without', 'IN'),
#  ('pictures', 'NNS'),
#  ('conversation', 'VBP'),
#  ('considering', 'VBG'),
#  ('mind', 'RB'),
#  ('well', 'RB'),
#  ('hot', 'JJ'),
#  ('day', 'NN'),
#  ('made', 'VBD'),
#  ('feel', 'NN'),
#  ('sleepy', 'JJ'),
#  ('stupid', 'JJ'),
#  ('whether', 'IN'),
#  ('pleasure', 'NN'),
#  ('making', 'VBG'),
#  ('daisy', 'NN'),
#  ('chain', 'NN'),
#  ('worth', 'IN'),
# ...
